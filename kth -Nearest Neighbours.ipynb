# %% [markdown]
# # kth-nearest neighbours

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
plt.style.use('seaborn')

# %%
#reading the data

# %%
dfx = pd.read_csv('Diabetes_XTrain.csv')
dfy = pd.read_csv('Diabetes_YTrain.csv')
dfx.head
# Out:
# <bound method NDFrame.head of      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              7      168             88             42      321  38.2
# 1              8      110             76              0        0  27.8
# 2              7      147             76              0        0  39.4
# 3              2      100             66             20       90  32.9
# 4              4      129             86             20      270  35.1
# ..           ...      ...            ...            ...      ...   ...
# 571            2      111             60              0        0  26.2
# 572            7      187             68             39      304  37.7
# 573            2      122             60             18      106  29.8
# 574            4      154             72             29      126  31.3
# 575            1       88             78             29       76  32.0
#
#      DiabetesPedigreeFunction  Age
# 0                       0.787   40
# ...

# %%
#generating numpy array

X = dfx.values
Y = dfy.values

#print(X)
# no serial no hence no need to drop any of the columns or rows 
# print(Y)

print(X.shape)
print(Y.shape)

# we need to reshape the Y from row to column
# Out:
# (576, 8)
# (576, 1)

# %%
print(X[0,])
# Out:
# [  7.    168.     88.     42.    321.     38.2     0.787  40.   ]

# %%
plt.scatter(X[:,5],X[:,6],c=Y)
plt.show()

# %%
# test_df = pd.read_csv('Diabetes_Xtest.csv')
# test_X = test_df.values

test_X = np.array([40,0.5])

plt.scatter(X[:,5],X[:,6],c=Y)
plt.scatter(test_X[:,0],test_X[:,1],c='red')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_34072/3068993470.py in <module>
#       5
#       6 plt.scatter(X[:,5],X[:,6],c=Y)
# ----> 7 plt.scatter(test_X[:,0],test_X[:,1],c='red')
#       8 plt.show()
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
def Eucledian_dist(X1,X2):
    return np.sqrt(sum((X1-X2)**2))

def KNN(X,Y,test_X,K=5):
    vals = [] 
    # a list of tuples 
    m = X.shape[0]
    
    for i in range(m):
        d = Eucledian_dist(test_X,X[i])
        vals.append((d,Y[i]))
        
        
    vals = sorted(vals)
    vals = vals[0:k:1]
    
    v = np.unique(vals[: :1],return_count=True)
    #both the np arrays got stored in the vals the elements[0] and their counts[1] 
    idx = v[1].argmax()
    pred = v[0][idx]
    
    return pred

# %%
for i in range (test_X.shape[0]):
    pred = KNN(train_X,train_Y,test_X[i],5)
    test_Y[i]=pred
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_34072/4148784566.py in <module>
#       1 for i in range (test_X.shape[0]):
# ----> 2     pred = KNN(train_X,train_Y,test_X[i],5)
#       3     test_Y[i]=pred
#
# NameError: name 'train_X' is not defined
